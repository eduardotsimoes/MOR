# %%
import numpy as np

# %%
x = list(np.arange(-1.,1.,0.001))

# %%
import math as mt

MI = list(np.arange(1.,mt.pi,2.0/51.0))

# %%
import matplotlib.pyplot as plt 

snapshots =[]
for mi in MI:
    y = list(map(lambda x : (1-x)*mt.cos(mt.pi*3*mi*(x+1))*mt.exp(-(1+x)*mi) , x))
    snapshots.append(y[:])  
    # plotting the points  
    plt.plot(x,y) 

# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('A nonlinear parametrized function with spatial points in one dimension.') 
  
# function to show the plot 
plt.show()

# %%
snaps = np.array(snapshots)
snaps.shape
# Out:
# (55, 2000)

# %%
u, s, vh = np.linalg.svd(snaps, full_matrices=True)

# %%
u.shape
# Out:
# (55, 55)

# %%
for i in range(0,5):
    plt.plot(x,vh[i])


plt.title('First six modes.') 
plt.show()

# %%
arr = np.array([])

# Step 1

maxE = np.amax(snaps[0])
index = np.where(snaps[0]==maxE)[0][0]
E1 = np.zeros(2000)
E1[index]=1.0
U1=snaps[0,:]
arr = np.append(arr,index)

# Step 2
a = np.transpose(E1).dot(U1)
U2 = snaps[1,:]
b = np.transpose(E1).dot(U2)
c = b/a # np.solve must be minimal two dimensional
r= U2 -U1*c
maxE = np.amax(r)
index = np.where(r==maxE)[0][0]
arr = np.append(arr,index)
E2 = np.zeros(2000)
E2[index]=1.0
P = np.vstack((E1, E2))
U = np.vstack((U1, U2))

# Step 3
U3=snaps[2]
c = np.linalg.solve(np.dot(P,np.transpose(U)),np.dot(P,np.transpose(U3)))
r= U3 -np.dot(c,U)
maxE = np.amax(r)
index = np.where(r==maxE)[0][0]
arr = np.append(arr,index)
E3 = np.zeros(2000)
E3[index]=1.0
P = np.vstack((P, E3))
U = np.vstack((U, U3))

# Step 4
U4=snaps[3]
c = np.linalg.solve(np.dot(P,np.transpose(U)),np.dot(P,np.transpose(U4)))
r= U4 -np.dot(c,U)
maxE = np.amax(r)
index = np.where(r==maxE)
arr = np.append(arr,index)
E4 = np.zeros(2000)
E4[index]=1.0
P = np.vstack((P, E4))
U = np.vstack((U, U4))


# Step 4
U5=snaps[3]
c = np.linalg.solve(np.dot(P,np.transpose(U)),np.dot(P,np.transpose(U5)))
r= U5 -np.dot(c,U)
maxE = np.amax(r)
index = np.where(r==maxE)
arr = np.append(arr,index)
E5 = np.zeros(2000)
E5[index]=1.0
P = np.vstack((P, E5))
U = np.vstack((U, U5))

# %%
s.shape
modes = np.arange(0,55)

plt.semilogy(modes,s)

# %%
arr
# Out:
# array([   0.,  484.,  954., 1405.])

# %%
for i in range(0,5):
    plt.plot(x,vh[i])

pos = np.array([])    
for i in range(0,arr.shape[0]):
    pos=np.append(pos,x[int(arr[i])])

yy = np.zeros(arr.shape[0])
    
plt.plot(pos, yy, 'o', color='black');

plt.title('First six modes.') 
plt.show()
pos
# Out:
# array([-1.   , -0.516, -0.046,  0.405, -0.943])

# %%
pos
# Out:
# array([-1.   , -0.999, -0.998, -0.997])
