# %%
import numpy as np

# %%
x = list(np.arange(-1.,1.,0.001))

# %%
import math as mt

MI = list(np.arange(1.,mt.pi,2.0/51.0))

# %%
import matplotlib.pyplot as plt 

snapshots =[]
for mi in MI:
    y = list(map(lambda x : (1-x)*mt.cos(mt.pi*3*mi*(x+1))*mt.exp(-(1+x)*mi) , x))
    snapshots.append(y[:])  
    # plotting the points  
    plt.plot(x,y) 

# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('A nonlinear parametrized function with spatial points in one dimension.') 
  
# function to show the plot 
plt.show()

# %%
snaps = np.array(snapshots)
snaps.shape
# Out:
# (55, 2000)

# %%
u, s, vh = np.linalg.svd(snaps, full_matrices=True)

# %%
u.shape
# Out:
# (55, 55)

# %%
for i in range(0,5):
    plt.plot(x,vh[i])


plt.title('First six modes.') 
plt.show()

# %%
arr = np.array([])

maxE = np.amax(vh[0])
index = np.where(vh[0]==maxE)[0][0]
index
arr = np.append(arr,index)
arr
# Out:
# array([154.])

# %%
arr = np.array([])

# Step 1

maxE = np.amax(vh[0])
index = np.where(vh[0]==maxE)[0][0]
arr = np.append(arr,index)

E1 = np.zeros(2000)
E1[index]=1.0
U1=snaps[0,:]


# Step 2
a = np.transpose(E1).dot(U1)
U2 = vh[1,:]
b = np.transpose(E1).dot(U2)
c = b/a # np.solve must be minimal two dimensional
r= U2 -U1*c
maxE = np.amax(r)
index = np.where(r==maxE)[0][0]
arr = np.append(arr,index)

E2 = np.zeros(2000)
E2[index]=1.0
P = np.vstack((E1, E2))
U = np.vstack((U1, U2))

# Step 3
U3=vh[2]
c = np.linalg.solve(np.dot(P,np.transpose(U)),np.dot(P,np.transpose(U3)))
r= U3 -np.dot(c,U)
maxE = np.amax(r)
index = np.where(r==maxE)[0][0]
#arr = np.append(arr,index)
E3 = np.zeros(2000)
E3[index]=1.0
P = np.vstack((P, E3))
U = np.vstack((U, U3))

# Step 4
U4=vh[3]
c = np.linalg.solve(np.dot(P,np.transpose(U)),np.dot(P,np.transpose(U4)))
r= U4 -np.dot(c,U)
maxE = np.amax(r)
index = np.where(r==maxE)
#arr = np.append(arr,index)
E4 = np.zeros(2000)
E4[index]=1.0
P = np.vstack((P, E4))
U = np.vstack((U, U4))


# Step 4
U5=vh[3]
c = np.linalg.solve(np.dot(P,np.transpose(U)),np.dot(P,np.transpose(U5)))
r= U5 -np.dot(c,U)
maxE = np.amax(r)
index = np.where(r==maxE)
#arr = np.append(arr,index)
E5 = np.zeros(2000)
E5[index]=1.0
P = np.vstack((P, E5))
U = np.vstack((U, U5))

# %%
s.shape
modes = np.arange(0,55)

plt.semilogy(modes,s)

# %%
arr
# Out:
# array([154.,   0.])

# %%
for i in range(0,5):
    plt.plot(x,vh[i])

pos = np.array([])    
for i in range(0,arr.shape[0]):
    pos=np.append(pos,x[int(arr[i])])

yy = np.zeros(arr.shape[0])
    
plt.plot(pos, yy, 'o', color='black');

plt.title('First six modes.') 
plt.show()
pos
# Out:
# array([-0.846, -1.   , -0.91 , -0.408, -0.77 , -0.769, -0.759, -0.758,
#        -0.757, -0.756, -0.755, -0.754, -0.753, -0.752, -0.751, -0.75 ,
#        -0.749, -0.748, -0.747, -0.746, -0.745, -0.744, -0.743, -0.742,
#        -0.741, -0.74 , -0.739, -0.738, -0.737, -0.736, -0.735, -0.734,
#        -0.733, -0.732, -0.731, -0.73 , -0.729, -0.728, -0.727, -0.726,
#        -0.725, -0.724, -0.723, -0.722, -0.721, -0.72 , -0.719, -0.718,
#        -0.717, -0.716, -0.715, -0.714, -0.713, -0.712, -0.711, -0.71 ,
#        -0.709, -0.708, -0.707, -0.706, -0.705, -0.704, -0.703, -0.702,
#        -0.701, -0.7  , -0.699, -0.698, -0.697, -0.696, -0.695, -0.694,
#        -0.693, -0.692, -0.691, -0.69 , -0.689, -0.688, -0.687, -0.686,
#        -0.685, -0.684, -0.683, -0.466, -0.465, -0.464, -0.463, -0.462,
#        -0.461, -0.46 , -0.459, -0.458, -0.457, -0.456, -0.455, -0.45 ,
#        -0.449, -0.448, -0.447, -0.446, -0.445, -0.444, -0.443, -0.442,
#        -0.441, -0.44 , -0.439, -0.438, -0.437, -0.436, -0.435, -0.434,
#        -0.433, -0.432, -0.431, -0.43 , -0.429, -0.428, -0.427, -0.426,
#        -0.425, -0.424, -0.423, -0.422, -0.421, -0.42 , -0.419, -0.418,
#        -0.417, -0.416, -0.415, -0.414, -0.413, -0.412, -0.411, -0.41 ,
#        -0.409, -0.408, -0.407, -0.406, -0.405, -0.404, -0.403, -0.402,
#        -0.401, -0.4  , -0.399, -0.398, -0.397, -0.396, -0.395, -0.394,
#        -0.393, -0.392, -0.391, -0.39 , -0.389, -0.388, -0.387, -0.386,
#        -0.385, -0.384, -0.383, -0.382, -0.381, -0.38 , -0.379, -0.378,
#        -0.377, -0.376, -0.375, -0.374, -0.373, -0.372, -0.371, -0.37 ,
#        -0.369, -0.368, -0.367, -0.366, -0.365, -0.364, -0.363, -0.362,
#        -0.361, -0.36 , -0.359, -0.358, -0.357, -0.356, -0.355, -0.354,
#        -0.353, -0.352, -0.351, -0.35 , -0.349, -0.348, -0.347, -0.346,
#        -0.345, -0.344, -0.343, -0.342, -0.341, -0.34 , -0.339, -0.338,
#        -0.337, -0.336, -0.335, -0.334, -0.333])

# %%
pos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-634e55b6deee> in <module>
# ----> 1 pos
#
# NameError: name 'pos' is not defined
